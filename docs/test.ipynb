# %%
# !pip install jiwer
from jiwer import wer

ref = "Tôi tên là Nguyễn Văn A"
hyp = "Tôi là Nguyễn Văn A"

error = wer(ref, hyp)
print(f"ACC: {1 - error:.2%}")
# Out:
# ...
# ACC: 83.33%
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\envs\gpu\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\envs\gpu\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\envs\gpu\lib\site-packages)

# %%
1 - (1/6)
# Out:
# 0.8333333333333334
